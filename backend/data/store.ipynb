# %%
import logging
import os
import re
from pathlib import Path

import numpy as np
import pandas as pd
import pypsa
from pypsa.descriptors import get_switchable_as_dense as get_as_dense
from pypsa.linopf import (
    define_constraints,
    define_variables,
    get_var,
    ilopf,
    join_exprs,
    linexpr,
    network_lopf,
)

logger = logging.getLogger(__name__)
# Out:
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\networkclustering.py:16: UserWarning:
#
# The namespace `pypsa.networkclustering` is deprecated and will be removed in PyPSA v0.24. Please use `pypsa.clustering.spatial instead`.

# %%
def add_RES_constraints(n, res_share):
    lgrouper = n.loads.bus.map(n.buses.country)
    ggrouper = n.generators.bus.map(n.buses.country)
    sgrouper = n.storage_units.bus.map(n.buses.country)
    cgrouper = n.links.bus0.map(n.buses.country)
    logger.warning(
        "The add_RES_constraints functionality is still work in progress. "
        "Unexpected results might be incurred, particularly if "
        "temporal clustering is applied or if an unexpected change of technologies "
        "is subject to the obtimisation."
    )
    load = (
        n.snapshot_weightings.generators
        @ n.loads_t.p_set.groupby(lgrouper, axis=1).sum()
    )
    rhs = res_share * load
    res_techs = [
        "solar",
        "onwind",
        "offwind-dc",
        "offwind-ac",
        "battery",
        "hydro",
        "ror",
    ]
    charger = ["H2 electrolysis", "battery charger"]
    discharger = ["H2 fuel cell", "battery discharger"]
    gens_i = n.generators.query("carrier in @res_techs").index
    stores_i = n.storage_units.query("carrier in @res_techs").index
    charger_i = n.links.query("carrier in @charger").index
    discharger_i = n.links.query("carrier in @discharger").index
    # Generators
    lhs_gen = (
        linexpr(
            (n.snapshot_weightings.generators, get_var(n, "Generator", "p")[gens_i].T)
        )
        .T.groupby(ggrouper, axis=1)
        .apply(join_exprs)
    )
    # StorageUnits
    lhs_dispatch = (
        (
            linexpr(
                (
                    n.snapshot_weightings.stores,
                    get_var(n, "StorageUnit", "p_dispatch")[stores_i].T,
                )
            )
            .T.groupby(sgrouper, axis=1)
            .apply(join_exprs)
        )
        .reindex(lhs_gen.index)
        .fillna("")
    )
    lhs_store = (
        (
            linexpr(
                (
                    -n.snapshot_weightings.stores,
                    get_var(n, "StorageUnit", "p_store")[stores_i].T,
                )
            )
            .T.groupby(sgrouper, axis=1)
            .apply(join_exprs)
        )
        .reindex(lhs_gen.index)
        .fillna("")
    )
    # Stores (or their resp. Link components)
    # Note that the variables "p0" and "p1" currently do not exist.
    # Thus, p0 and p1 must be derived from "p" (which exists), taking into account the link efficiency.
    lhs_charge = (
        (
            linexpr(
                (
                    -n.snapshot_weightings.stores,
                    get_var(n, "Link", "p")[charger_i].T,
                )
            )
            .T.groupby(cgrouper, axis=1)
            .apply(join_exprs)
        )
        .reindex(lhs_gen.index)
        .fillna("")
    )
    lhs_discharge = (
        (

            linexpr(
                (
                    n.snapshot_weightings.stores.apply(
                        lambda r: r * n.links.loc[discharger_i].efficiency
                    ),
                    get_var(n, "Link", "p")[discharger_i],
                )
            )
            .groupby(cgrouper, axis=1)
            .apply(join_exprs)
        )
        .reindex(lhs_gen.index)
        .fillna("")
    )
    # signs of resp. terms are coded in the linexpr.
    # todo: for links (lhs_charge and lhs_discharge), account for snapshot weightings
    lhs = lhs_gen + lhs_dispatch + lhs_store + lhs_charge + lhs_discharge
    define_constraints(n, lhs, "=", rhs, "RES share")
# Define RES shares and storage levels
res_shares = np.round(np.arange(0.10, 0.65, 0.05), 2)
storage_levels = list(range(0, 6))  # 0 to 5
base_path = os.getcwd()
base_filename = "elec_s_14_ec_lv1.0_RES{:.2f}-1H_dle.nc"
for res in res_shares:
    base_file = os.path.join(base_path, base_filename.format(res))
    
    if not os.path.exists(base_file):
        print(f"[!] Base file not found for RES {res:.2f}: {base_file}")
        continue

    print(f"\n=== RES {res:.2f} ===")
    for storage_level in storage_levels:
        print(f"  → Running with storage level {storage_level}")
        # Load base network
        n =pypsa.Network(base_file)
        for tech in ["battery", "H2"]:
            mask = n.storage_units.carrier == tech
            if storage_level == 0:
                # Disable storage
                n.storage_units.loc[mask, "p_nom_max"] = 0.0
                n.storage_units.loc[mask, "p_nom_min"] = 0.0
                n.storage_units.loc[mask, "p_nom"] = 0.0
                n.storage_units.loc[mask, "p_nom_extendable"] = False
            else:
                # Scale duration and capacity
                n.storage_units.loc[mask, "max_hours"] = (
                    n.storage_units.loc[mask, "max_hours"].astype(float) * storage_level
                )
                n.storage_units.loc[mask, "p_nom_max"] = (
                    n.storage_units.loc[mask, "p_nom_max"].astype(float) * storage_level
                )
                n.storage_units.loc[mask, "p_nom_extendable"] = True
        # Solve the network
        try:
            def make_extra_functionality(res_share):
                return lambda n, snapshots: add_RES_constraints(n, res_share)
            extra_func = make_extra_functionality(res)
            network_lopf(
                n,
                solver_name="cplex",
                solver_options = {
                    "threads": 4,
                    "workmem": 256,
                    "workdir": "./cplex_tmp",
                    "mip.tolerances.mipgap": 0.05,
                    "emphasis.memory": 1,                  # Prioritize memory conservation
                    "mip.limits.treememory": 512,         # Limit tree memory (MB)
                    "mip.strategy.file": 3,                # Write node files to disk (for large trees)
                    "mip.strategy.nodeselect": 1,          # Use best estimate node selection (less memory use)
                    "mip.strategy.variableselect": 4,      # Pseudocost branching (faster)
                    "mip.strategy.bbinterval": 100,        # Fewer backtracking intervals
                    "mip.limits.nodes": 50000  
                },
                extra_functionality=extra_func
            )
        except Exception as e:
            print(f"    [x] Optimization failed for RES {res} + Storage {storage_level}: {e}")
            continue
        # Save solved network
        output_file = f"{base_path}/elec_s_14_ec_lv1.0_RES{res:.2f}_STORAGE{storage_level}-1H_dle.nc"
        n.export_to_netcdf(output_file)
        print(f"    Saved to {output_file}")
# Out:
# [!] Base file not found for RES 0.10: c:\Users\bakht\Desktop\project\pypsa-earth\results\kz_default_2018_one_year1\networks\elec_s_14_ec_lv1.0_RES0.10-1H_dle.nc
#
# === RES 0.15 ===
#   → Running with storage level 0
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# INFO:pypsa.io:Imported network elec_s_14_ec_lv1.0_RES0.15-1H_dle.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# WARNING:pypsa.linopf:Unit commitment is not yet completely implemented for optimising without pyomo. Thus minimum up time, minimum down time, start up costs, shut down costs will be ignored.
# INFO:pypsa.linopf:Prepare linear problem
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:530: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:538: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# WARNING:__main__:The add_RES_constraints functionality is still work in progress. Unexpected results might be incurred, particularly if temporal clustering is applied or if an unexpected change of technologies is subject to the obtimisation.
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:14: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:34: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:43: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:57: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:74: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:89: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# INFO:pypsa.linopf:Total preparation time: 18.92s
# INFO:pypsa.linopf:Solve linear problem using Cplex solver
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 4
# CPXPARAM_Emphasis_Memory                         1
# CPXPARAM_MIP_Strategy_File                       3
# CPXPARAM_MIP_Strategy_VariableSelect             4
# CPXPARAM_MIP_Limits_Nodes                        50000
# CPXPARAM_MIP_Strategy_BBInterval                 100
# CPXPARAM_WorkMem                                 256
# CPXPARAM_MIP_Tolerances_MIPGap                   0.050000000000000003
# CPXPARAM_MIP_Limits_TreeMemory                   512
# CPXPARAM_WorkDir                                 "./cplex_tmp"
# Tried aggregator 2 times.
# MIP Presolve eliminated 4075652 rows and 867422 columns.
# Aggregator did 359160 substitutions.
# Reduced MIP has 2432937 rows, 1804508 columns, and 9094390 nonzeros.
# Reduced MIP has 201480 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 6.02 sec. (7401.05 ticks)
# Found incumbent of value 2.5810991e+12 after 15.88 sec. (18496.50 ticks)
# Elapsed time = 38.59 sec. (10001.77 ticks) for 1% of probing
# Elapsed time = 66.66 sec. (20003.54 ticks) for 2% of probing
# Elapsed time = 94.88 sec. (30005.32 ticks) for 3% of probing
# Elapsed time = 122.94 sec. (40006.99 ticks) for 3% of probing
# Elapsed time = 151.11 sec. (50008.66 ticks) for 4% of probing
# Elapsed time = 179.27 sec. (60010.37 ticks) for 5% of probing
# Elapsed time = 207.25 sec. (70012.14 ticks) for 6% of probing
# Elapsed time = 235.59 sec. (80013.85 ticks) for 7% of probing
# Elapsed time = 263.83 sec. (90015.67 ticks) for 8% of probing
# Elapsed time = 291.97 sec. (100017.37 ticks) for 9% of probing
# Elapsed time = 320.23 sec. (110019.10 ticks) for 9% of probing
# Elapsed time = 348.44 sec. (120020.89 ticks) for 10% of probing
# Elapsed time = 378.06 sec. (130022.62 ticks) for 11% of probing
# Elapsed time = 408.72 sec. (140024.40 ticks) for 12% of probing
# Elapsed time = 437.33 sec. (150026.13 ticks) for 13% of probing
# Elapsed time = 469.17 sec. (160027.88 ticks) for 14% of probing
# Elapsed time = 500.34 sec. (170029.65 ticks) for 14% of probing
# Elapsed time = 527.95 sec. (180031.43 ticks) for 15% of probing
# Elapsed time = 554.94 sec. (190033.20 ticks) for 16% of probing
# Elapsed time = 583.16 sec. (200034.96 ticks) for 17% of probing
# Elapsed time = 609.95 sec. (210036.75 ticks) for 18% of probing
# Elapsed time = 636.84 sec. (220038.46 ticks) for 19% of probing
# Elapsed time = 663.66 sec. (230040.22 ticks) for 20% of probing
# Probing time = 675.98 sec. (234645.00 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 16260 rows and 40281 columns.
# Reduced MIP has 2416677 rows, 1764227 columns, and 9045610 nonzeros.
# Reduced MIP has 161199 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 11.28 sec. (7001.06 ticks)
# Elapsed time = 61.49 sec. (10008.68 ticks) for 1% of probing
# Elapsed time = 127.56 sec. (20016.82 ticks) for 1% of probing
# Elapsed time = 183.27 sec. (30016.91 ticks) for 2% of probing
# Elapsed time = 245.06 sec. (40023.52 ticks) for 3% of probing
# Elapsed time = 299.42 sec. (50030.43 ticks) for 3% of probing
# Elapsed time = 353.58 sec. (60032.01 ticks) for 4% of probing
# Elapsed time = 405.67 sec. (70034.69 ticks) for 5% of probing
# Elapsed time = 466.17 sec. (80034.78 ticks) for 5% of probing
# Elapsed time = 519.78 sec. (90041.16 ticks) for 6% of probing
# Elapsed time = 569.55 sec. (100042.87 ticks) for 7% of probing
# Elapsed time = 617.06 sec. (110045.57 ticks) for 7% of probing
# Elapsed time = 667.94 sec. (120050.47 ticks) for 8% of probing
# Elapsed time = 720.28 sec. (130053.12 ticks) for 9% of probing
# Elapsed time = 774.56 sec. (140060.48 ticks) for 9% of probing
# Elapsed time = 826.52 sec. (150064.84 ticks) for 10% of probing
# Elapsed time = 877.69 sec. (160065.73 ticks) for 11% of probing
# Elapsed time = 930.92 sec. (170071.85 ticks) for 11% of probing
# Elapsed time = 983.25 sec. (180078.16 ticks) for 12% of probing
# Elapsed time = 1034.92 sec. (190078.91 ticks) for 13% of probing
# Elapsed time = 1086.70 sec. (200081.40 ticks) for 13% of probing
# Elapsed time = 1139.39 sec. (210082.11 ticks) for 14% of probing
# Elapsed time = 1190.24 sec. (220084.63 ticks) for 15% of probing
# Elapsed time = 1239.31 sec. (230085.91 ticks) for 15% of probing
# Elapsed time = 1287.94 sec. (240091.29 ticks) for 16% of probing
# Elapsed time = 1339.09 sec. (250095.70 ticks) for 17% of probing
# Elapsed time = 1389.22 sec. (260102.45 ticks) for 17% of probing
# Elapsed time = 1436.77 sec. (270104.36 ticks) for 18% of probing
# Elapsed time = 1485.30 sec. (280106.12 ticks) for 19% of probing
# Elapsed time = 1533.70 sec. (290113.35 ticks) for 19% of probing
# Elapsed time = 1582.14 sec. (300121.28 ticks) for 20% of probing
# Elapsed time = 1630.67 sec. (310128.52 ticks) for 21% of probing
# Elapsed time = 1677.58 sec. (320137.23 ticks) for 21% of probing
# Elapsed time = 1720.77 sec. (330145.27 ticks) for 22% of probing
# Elapsed time = 1764.81 sec. (340146.28 ticks) for 23% of probing
# Elapsed time = 1806.24 sec. (350150.75 ticks) for 23% of probing
# Elapsed time = 1845.55 sec. (360156.44 ticks) for 24% of probing
# Elapsed time = 1884.24 sec. (370161.03 ticks) for 25% of probing
# Elapsed time = 1923.25 sec. (380164.64 ticks) for 25% of probing
# Elapsed time = 1962.27 sec. (390170.88 ticks) for 26% of probing
# Elapsed time = 2001.83 sec. (400172.15 ticks) for 27% of probing
# Elapsed time = 2041.91 sec. (410176.13 ticks) for 27% of probing
# Elapsed time = 2082.14 sec. (420183.25 ticks) for 28% of probing
# Elapsed time = 2122.52 sec. (430190.57 ticks) for 29% of probing
# Elapsed time = 2165.06 sec. (440199.90 ticks) for 29% of probing
# Elapsed time = 2205.49 sec. (450207.99 ticks) for 30% of probing
# Elapsed time = 2245.88 sec. (460214.39 ticks) for 31% of probing
# Elapsed time = 2286.02 sec. (470216.14 ticks) for 31% of probing
# Elapsed time = 2326.19 sec. (480222.81 ticks) for 32% of probing
# Elapsed time = 2368.12 sec. (490226.61 ticks) for 33% of probing
# Elapsed time = 2408.44 sec. (500231.42 ticks) for 33% of probing
# Elapsed time = 2448.69 sec. (510239.77 ticks) for 34% of probing
# Elapsed time = 2489.08 sec. (520245.50 ticks) for 35% of probing
# Elapsed time = 2529.66 sec. (530252.22 ticks) for 35% of probing
# Elapsed time = 2570.59 sec. (540257.65 ticks) for 36% of probing
# Elapsed time = 2611.16 sec. (550260.26 ticks) for 37% of probing
# Elapsed time = 2651.41 sec. (560262.93 ticks) for 37% of probing
# Elapsed time = 2691.89 sec. (570266.27 ticks) for 38% of probing
# Probing time = 2698.44 sec. (571871.79 ticks)
# Clique table members: 6289056.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 46420.25 sec. (18676864.50 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       2.58110e+12        0.0002           100.00%
#       0     0   2.93960e+09 38247   2.58110e+12   2.93960e+09  2145714   99.89%
#       0     0   2.93960e+09 33689   2.58110e+12    Cuts: 9987  2149429   99.89%
#       0     0   2.93960e+09 31587   2.58110e+12    Cuts: 9998  2152160   99.89%
#       0     0   2.93960e+09 28437   2.58110e+12    Cuts: 9999  2154162   99.89%
#       0     0   2.93960e+09 27509   2.58110e+12    Cuts: 9997  2156648   99.89%
#       0     0   2.93960e+09 26272   2.58110e+12    Cuts: 9997  2159028   99.89%
# Detecting symmetries...
#       0     0   2.93960e+09 20957   2.58110e+12    Cuts: 9986  2165318   99.89%
#       0     0   2.93960e+09 15110   2.58110e+12    Cuts: 9975  2170217   99.89%
#       0     0   2.93960e+09 13258   2.58110e+12   Cuts: 10000  2171701   99.89%
#       0     0   2.93960e+09  9774   2.58110e+12    Cuts: 9966  2175789   99.89%
#       0     0   2.93960e+09  8424   2.58110e+12    Cuts: 9989  2177143   99.89%
#       0     0   2.93960e+09  5778   2.58110e+12    Cuts: 9978  2179699   99.89%
# *     0+    0                       2.93960e+09   2.93960e+09             0.00%
#       0     0        cutoff         2.93960e+09   2.93960e+09  2179699    0.00%
# Elapsed time = 71269.47 sec. (26654116.65 ticks, tree = 0.01 MB, solutions = 2)
#
# Clique cuts applied:  45437
# Implied bound cuts applied:  41095
# Flow cuts applied:  115
# Mixed integer rounding cuts applied:  8692
# Gomory fractional cuts applied:  26
#
# Root node processing (before b&c):
#   Real time             = 71269.91 sec. (26654276.84 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) = 71269.91 sec. (26654276.84 ticks)
# WARNING:pypsa.linopt:Shadow prices of MILP couldn't be parsed
# INFO:pypsa.linopf:Optimization successful. Objective value: 2.94e+09
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:1281: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:1281: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:1343: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:1415: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# INFO:pypsa.io:Exported network elec_s_14_ec_lv1.0_RES0.15_STORAGE0-1H_dle.nc has lines, generators, loads, stores, buses, carriers, links, global_constraints, storage_units
#     Saved to c:\Users\bakht\Desktop\project\pypsa-earth\results\kz_default_2018_one_year1\networks/elec_s_14_ec_lv1.0_RES0.15_STORAGE0-1H_dle.nc
#   → Running with storage level 1
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# INFO:pypsa.io:Imported network elec_s_14_ec_lv1.0_RES0.15-1H_dle.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# WARNING:pypsa.linopf:Unit commitment is not yet completely implemented for optimising without pyomo. Thus minimum up time, minimum down time, start up costs, shut down costs will be ignored.
# INFO:pypsa.linopf:Prepare linear problem
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:530: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:538: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# WARNING:__main__:The add_RES_constraints functionality is still work in progress. Unexpected results might be incurred, particularly if temporal clustering is applied or if an unexpected change of technologies is subject to the obtimisation.
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:14: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:34: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:43: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:57: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:74: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:89: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# INFO:pypsa.linopf:Total preparation time: 17.45s
# INFO:pypsa.linopf:Solve linear problem using Cplex solver
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 4
# CPXPARAM_Emphasis_Memory                         1
# CPXPARAM_MIP_Strategy_File                       3
# CPXPARAM_MIP_Strategy_VariableSelect             4
# CPXPARAM_MIP_Limits_Nodes                        50000
# CPXPARAM_MIP_Strategy_BBInterval                 100
# CPXPARAM_WorkMem                                 256
# CPXPARAM_MIP_Tolerances_MIPGap                   0.050000000000000003
# CPXPARAM_MIP_Limits_TreeMemory                   512
# CPXPARAM_WorkDir                                 "./cplex_tmp"
# Tried aggregator 2 times.
# MIP Presolve eliminated 3094532 rows and 131582 columns.
# Aggregator did 359160 substitutions.
# Reduced MIP has 3414057 rows, 2540376 columns, and 12283030 nonzeros.
# Reduced MIP has 201480 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 6.52 sec. (7920.34 ticks)
# Elapsed time = 41.09 sec. (10001.80 ticks) for 1% of probing
# Elapsed time = 70.41 sec. (20006.46 ticks) for 2% of probing
# Elapsed time = 99.55 sec. (30011.12 ticks) for 3% of probing
# Elapsed time = 128.53 sec. (40015.81 ticks) for 3% of probing
# Elapsed time = 157.94 sec. (50020.50 ticks) for 4% of probing
# Elapsed time = 186.02 sec. (60025.27 ticks) for 5% of probing
# Elapsed time = 218.45 sec. (70029.96 ticks) for 6% of probing
# Elapsed time = 246.30 sec. (80034.70 ticks) for 7% of probing
# Elapsed time = 274.97 sec. (90039.44 ticks) for 8% of probing
# Elapsed time = 305.88 sec. (100044.17 ticks) for 9% of probing
# Elapsed time = 335.49 sec. (110048.91 ticks) for 9% of probing
# Elapsed time = 364.83 sec. (120053.57 ticks) for 10% of probing
# Elapsed time = 393.41 sec. (130058.33 ticks) for 11% of probing
# Elapsed time = 420.88 sec. (140062.97 ticks) for 12% of probing
# Elapsed time = 449.17 sec. (150067.67 ticks) for 13% of probing
# Elapsed time = 476.67 sec. (160072.40 ticks) for 14% of probing
# Elapsed time = 504.49 sec. (170077.08 ticks) for 14% of probing
# Elapsed time = 539.52 sec. (180081.78 ticks) for 15% of probing
# Elapsed time = 581.00 sec. (190086.48 ticks) for 16% of probing
# Elapsed time = 619.05 sec. (200091.20 ticks) for 17% of probing
# Elapsed time = 662.81 sec. (210095.90 ticks) for 18% of probing
# Elapsed time = 701.83 sec. (220100.57 ticks) for 19% of probing
# Elapsed time = 730.78 sec. (230105.20 ticks) for 20% of probing
# Elapsed time = 779.30 sec. (240109.90 ticks) for 20% of probing
# Elapsed time = 831.78 sec. (250114.61 ticks) for 21% of probing
# Elapsed time = 870.44 sec. (260119.35 ticks) for 22% of probing
# Elapsed time = 897.80 sec. (270124.04 ticks) for 23% of probing
# Elapsed time = 925.22 sec. (280128.69 ticks) for 24% of probing
# Elapsed time = 952.52 sec. (290133.30 ticks) for 25% of probing
# Elapsed time = 979.97 sec. (300138.00 ticks) for 26% of probing
# Elapsed time = 1007.50 sec. (310142.67 ticks) for 26% of probing
# Elapsed time = 1051.78 sec. (320147.32 ticks) for 27% of probing
# Probing time = 1101.56 sec. (329893.59 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 31776 rows and 56626 columns.
# Reduced MIP has 3382281 rows, 2483750 columns, and 12187702 nonzeros.
# Reduced MIP has 144854 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 25.84 sec. (9364.51 ticks)
# Elapsed time = 61.27 sec. (10000.74 ticks) for 1% of probing
# Elapsed time = 117.12 sec. (20004.66 ticks) for 1% of probing
# Elapsed time = 166.56 sec. (30010.40 ticks) for 2% of probing
# Elapsed time = 216.42 sec. (40020.72 ticks) for 3% of probing
# Elapsed time = 263.45 sec. (50024.78 ticks) for 3% of probing
# Elapsed time = 308.09 sec. (60032.94 ticks) for 4% of probing
# Elapsed time = 354.61 sec. (70040.74 ticks) for 4% of probing
# Elapsed time = 402.55 sec. (80044.24 ticks) for 5% of probing
# Elapsed time = 449.16 sec. (90044.95 ticks) for 6% of probing
# Elapsed time = 493.64 sec. (100053.58 ticks) for 6% of probing
# Elapsed time = 545.64 sec. (110058.05 ticks) for 7% of probing
# Elapsed time = 591.92 sec. (120059.25 ticks) for 8% of probing
# Elapsed time = 638.22 sec. (130061.80 ticks) for 8% of probing
# Elapsed time = 681.20 sec. (140072.30 ticks) for 9% of probing
# Elapsed time = 720.72 sec. (150077.05 ticks) for 9% of probing
# Elapsed time = 753.31 sec. (160080.70 ticks) for 10% of probing
# Elapsed time = 789.02 sec. (170083.23 ticks) for 11% of probing
# Elapsed time = 824.27 sec. (180094.09 ticks) for 11% of probing
# Elapsed time = 863.69 sec. (190102.84 ticks) for 12% of probing
# Elapsed time = 899.88 sec. (200105.15 ticks) for 12% of probing
# Elapsed time = 935.61 sec. (210115.54 ticks) for 13% of probing
# Elapsed time = 970.49 sec. (220117.89 ticks) for 14% of probing
# Elapsed time = 1004.80 sec. (230120.30 ticks) for 14% of probing
# Elapsed time = 1039.17 sec. (240129.19 ticks) for 15% of probing
# Elapsed time = 1072.67 sec. (250134.73 ticks) for 15% of probing
# Elapsed time = 1106.77 sec. (260135.67 ticks) for 16% of probing
# Elapsed time = 1141.20 sec. (270143.81 ticks) for 17% of probing
# Elapsed time = 1174.94 sec. (280149.75 ticks) for 17% of probing
# Elapsed time = 1209.95 sec. (290150.36 ticks) for 18% of probing
# Elapsed time = 1244.41 sec. (300152.36 ticks) for 19% of probing
# Elapsed time = 1278.36 sec. (310161.42 ticks) for 19% of probing
# Elapsed time = 1311.97 sec. (320164.75 ticks) for 20% of probing
# Elapsed time = 1346.67 sec. (330172.50 ticks) for 20% of probing
# Elapsed time = 1379.84 sec. (340181.87 ticks) for 21% of probing
# Elapsed time = 1414.94 sec. (350190.05 ticks) for 22% of probing
# Elapsed time = 1450.25 sec. (360191.56 ticks) for 22% of probing
# Elapsed time = 1484.52 sec. (370200.82 ticks) for 23% of probing
# Elapsed time = 1522.24 sec. (380203.55 ticks) for 23% of probing
# Elapsed time = 1555.31 sec. (390212.42 ticks) for 24% of probing
# Elapsed time = 1587.94 sec. (400219.40 ticks) for 25% of probing
# Elapsed time = 1621.05 sec. (410219.73 ticks) for 25% of probing
# Elapsed time = 1656.64 sec. (420224.28 ticks) for 26% of probing
# Elapsed time = 1690.44 sec. (430236.31 ticks) for 27% of probing
# Elapsed time = 1724.17 sec. (440249.74 ticks) for 27% of probing
# Elapsed time = 1757.44 sec. (450259.52 ticks) for 28% of probing
# Elapsed time = 1795.36 sec. (460259.92 ticks) for 28% of probing
# Elapsed time = 1829.72 sec. (470263.06 ticks) for 29% of probing
# Elapsed time = 1865.72 sec. (480267.28 ticks) for 30% of probing
# Elapsed time = 1899.95 sec. (490278.91 ticks) for 30% of probing
# Elapsed time = 1932.91 sec. (500288.02 ticks) for 31% of probing
# Elapsed time = 1965.08 sec. (510296.05 ticks) for 31% of probing
# Elapsed time = 1998.86 sec. (520304.58 ticks) for 32% of probing
# Elapsed time = 2031.58 sec. (530308.22 ticks) for 33% of probing
# Elapsed time = 2064.64 sec. (540311.19 ticks) for 33% of probing
# Elapsed time = 2098.30 sec. (550320.10 ticks) for 34% of probing
# Elapsed time = 2130.45 sec. (560326.42 ticks) for 35% of probing
# Elapsed time = 2162.36 sec. (570334.49 ticks) for 35% of probing
# Elapsed time = 2194.62 sec. (580339.54 ticks) for 36% of probing
# Elapsed time = 2227.30 sec. (590341.25 ticks) for 36% of probing
# Elapsed time = 2259.67 sec. (600341.91 ticks) for 37% of probing
# Elapsed time = 2292.42 sec. (610348.47 ticks) for 38% of probing
# Elapsed time = 2324.70 sec. (620350.00 ticks) for 38% of probing
# Elapsed time = 2356.56 sec. (630351.45 ticks) for 39% of probing
# Elapsed time = 2388.08 sec. (640358.34 ticks) for 39% of probing
# Elapsed time = 2419.72 sec. (650368.55 ticks) for 40% of probing
# Elapsed time = 2452.41 sec. (660370.06 ticks) for 41% of probing
# Elapsed time = 2484.02 sec. (670376.55 ticks) for 41% of probing
# Elapsed time = 2516.27 sec. (680383.10 ticks) for 42% of probing
# Probing time = 2534.74 sec. (686205.04 ticks)
# Clique table members: 8590108.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Compressing row and column files.
# Root relaxation solution time = 2675.75 sec. (1974608.99 ticks)
# Warning: MIP starts not constructed because of out-of-memory status.
# Root node processing (before b&c):
#   Real time             = 6389.12 sec. (3037909.34 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) = 6389.12 sec. (3037909.34 ticks)
# CPLEX Error  1001: Out of memory.
#     [x] Optimization failed for RES 0.15 + Storage 1: CPLEX Error  1001: Out of memory.
#   → Running with storage level 2
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# INFO:pypsa.io:Imported network elec_s_14_ec_lv1.0_RES0.15-1H_dle.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# WARNING:pypsa.linopf:Unit commitment is not yet completely implemented for optimising without pyomo. Thus minimum up time, minimum down time, start up costs, shut down costs will be ignored.
# INFO:pypsa.linopf:Prepare linear problem
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:530: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# c:\Users\bakht\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\linopf.py:538: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# WARNING:__main__:The add_RES_constraints functionality is still work in progress. Unexpected results might be incurred, particularly if temporal clustering is applied or if an unexpected change of technologies is subject to the obtimisation.
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:14: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:34: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:43: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:57: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:74: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# C:\Users\bakht\AppData\Local\Temp\ipykernel_25232\148908771.py:89: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#
# INFO:pypsa.linopf:Total preparation time: 18.99s
# INFO:pypsa.linopf:Solve linear problem using Cplex solver
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 4
# CPXPARAM_Emphasis_Memory                         1
# CPXPARAM_MIP_Strategy_File                       3
# CPXPARAM_MIP_Strategy_VariableSelect             4
# CPXPARAM_MIP_Limits_Nodes                        50000
# CPXPARAM_MIP_Strategy_BBInterval                 100
# CPXPARAM_WorkMem                                 256
# CPXPARAM_MIP_Tolerances_MIPGap                   0.050000000000000003
# CPXPARAM_MIP_Limits_TreeMemory                   512
# CPXPARAM_WorkDir                                 "./cplex_tmp"
# Tried aggregator 2 times.
# MIP Presolve eliminated 3094532 rows and 131582 columns.
# Aggregator did 359160 substitutions.
# Reduced MIP has 3414057 rows, 2540376 columns, and 12283030 nonzeros.
# Reduced MIP has 201480 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 10.76 sec. (7920.34 ticks)
